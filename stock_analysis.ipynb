# %%
from stock_analysis import StockAnalysis as stock

# %%
company = stock("CHS")
company.multiples
company.summary
company.chart
# Out:
# PE : 4.765
# PS : 0.295
# PB : 1.507
# EV/EBITDA : 10.414780004186978
# DEBT/EQUITY : 1.3194310992951352
# ROE : 0.17692889797098332
# DIVIDEND YIELD : 0.0
